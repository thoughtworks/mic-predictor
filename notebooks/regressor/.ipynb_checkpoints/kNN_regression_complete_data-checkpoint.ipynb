# %%
cd ../../
# Out:
# /Users/in-divye.singh/Documents/Projects/MIC_predictor

# %%
import json
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from notebooks.utils import *
import importlib
import sys
importlib.reload(sys.modules['notebooks.utils'])
from notebooks.utils import *

# %%
from sklearn.manifold import TSNE

# %%
avp_ic50 = pd.read_csv("data/raw/AVP-IC50Pred_train.csv")
ha_avp = pd.read_csv("data/raw/HA_AVP.csv")

df = pd.concat([avp_ic50[['Sequence', 'MIC']], ha_avp], axis=0).drop_duplicates(['Sequence']).reset_index(drop=True)
df = sequence_filtering(df)
# df = df.sample(frac=1).reset_index(drop=True)

# %%
results = pd.read_csv("results/knn_regressor_all_data_combination.csv", sep=';')

# %%
results
# Out:
#                                                  Data Regressor  \
# 0                                             aa_freq       KNN
# 1                                          dipep_freq       KNN
# 2                                         tripep_freq       KNN
# 3                                         avg_protvec       KNN
# 4                                physicochemical_prop       KNN
# 5                                  aa_freq+dipep_freq       KNN
# 6                                 aa_freq+tripep_freq       KNN
# 7                                 aa_freq+avg_protvec       KNN
# 8                        aa_freq+physicochemical_prop       KNN
# 9                              dipep_freq+tripep_freq       KNN
# 10                             dipep_freq+avg_protvec       KNN
# 11                    dipep_freq+physicochemical_prop       KNN
# 12                            tripep_freq+avg_protvec       KNN
# 13                   tripep_freq+physicochemical_prop       KNN
# 14                   avg_protvec+physicochemical_prop       KNN
# 15                     aa_freq+dipep_freq+tripep_freq       KNN
# 16                     aa_freq+dipep_freq+avg_protvec       KNN
# 17            aa_freq+dipep_freq+physicochemical_prop       KNN
# 18                    aa_freq+tripep_freq+avg_protvec       KNN
# 19           aa_freq+tripep_freq+physicochemical_prop       KNN
# 20           aa_freq+avg_protvec+physicochemical_prop       KNN
# 21                 dipep_freq+tripep_freq+avg_protvec       KNN
# 22        dipep_freq+tripep_freq+physicochemical_prop       KNN
# 23        dipep_freq+avg_protvec+physicochemical_prop       KNN
# 24       tripep_freq+avg_protvec+physicochemical_prop       KNN
# 25         aa_freq+dipep_freq+tripep_freq+avg_protvec       KNN
# 26  aa_freq+dipep_freq+tripep_freq+physicochemical...       KNN
# 27  aa_freq+dipep_freq+avg_protvec+physicochemical...       KNN
# 28  aa_freq+tripep_freq+avg_protvec+physicochemica...       KNN
# 29  dipep_freq+tripep_freq+avg_protvec+physicochem...       KNN
# 30  aa_freq+dipep_freq+tripep_freq+avg_protvec+phy...       KNN
#
#                                       Best_parameters          MSE        MAE  \
# 0    "{'metric': 'chebyshev', 'n_neighbors': 1, 'w...  4238.627327  32.290370
# 1    "{'metric': 'euclidean', 'n_neighbors': 1, 'w...  3578.824434  27.736770
# 2    "{'metric': 'chebyshev', 'n_neighbors': 1, 'w...  5870.207139  40.165073
# 3    "{'metric': 'chebyshev', 'n_neighbors': 1, 'w...  5264.466418  32.421390
# 4    "{'metric': 'euclidean', 'n_neighbors': 2, 'w...  4032.816185  32.126328
# 5    "{'metric': 'chebyshev', 'n_neighbors': 2, 'w...  2713.243562  28.995829
# 6    "{'metric': 'euclidean', 'n_neighbors': 2, 'w...  3078.615787  27.148469
# 7    "{'metric': 'euclidean', 'n_neighbors': 1, 'w...  3872.983691  29.606011
# 8    "{'metric': 'euclidean', 'n_neighbors': 2, 'w...  4032.815319  32.123870
# 9    "{'metric': 'euclidean', 'n_neighbors': 1, 'w...  3957.573630  28.775896
# 10   "{'metric': 'euclidean', 'n_neighbors': 1, 'w...  3812.866251  28.626046
# 11   "{'metric': 'euclidean', 'n_neighbors': 2, 'w...  4338.643744  32.704681
# 12   "{'metric': 'euclidean', 'n_neighbors': 1, 'w...  4392.751276  30.319710
# 13   "{'metric': 'euclidean', 'n_neighbors': 2, 'w...  4335.419158  32.664296
# 14   "{'metric': 'euclidean', 'n_neighbors': 2, 'w...  4341.027995  32.517268
# 15   "{'metric': 'chebyshev', 'n_neighbors': 1, 'w...  5004.976604  34.010200
# 16   "{'metric': 'chebyshev', 'n_neighbors': 3, 'w...  2906.852170  30.462637
# 17   "{'metric': 'euclidean', 'n_neighbors': 2, 'w...  4338.552297  32.700946
# 18   "{'metric': 'euclidean', 'n_neighbors': 1, 'w...  4469.164472  30.907340
# 19   "{'metric': 'euclidean', 'n_neighbors': 2, 'w...  4335.356502  32.666586
# 20   "{'metric': 'euclidean', 'n_neighbors': 2, 'w...  4341.027995  32.517268
# 21   "{'metric': 'euclidean', 'n_neighbors': 1, 'w...  4067.402527  28.639815
# 22   "{'metric': 'euclidean', 'n_neighbors': 2, 'w...  4335.174994  32.653579
# 23   "{'metric': 'euclidean', 'n_neighbors': 2, 'w...  4353.697911  32.805415
# 24   "{'metric': 'euclidean', 'n_neighbors': 2, 'w...  4337.730653  32.469209
# 25   "{'metric': 'chebyshev', 'n_neighbors': 1, 'w...  3780.234082  29.812284
# 26   "{'metric': 'euclidean', 'n_neighbors': 2, 'w...  4335.181708  32.655859
# 27   "{'metric': 'euclidean', 'n_neighbors': 2, 'w...  4353.705690  32.809408
# 28   "{'metric': 'euclidean', 'n_neighbors': 2, 'w...  4353.634235  32.800247
# 29   "{'metric': 'euclidean', 'n_neighbors': 2, 'w...  4337.572838  32.465992
# 30   "{'metric': 'euclidean', 'n_neighbors': 2, 'w...  4337.572838  32.465992
#
#             MAPE
# 0   4.607780e+06
# 1   4.536848e+06
# 2   9.121888e+05
# 3   1.443086e+06
# 4   2.141575e+05
# 5   2.274189e+06
# 6   2.358213e+06
# 7   8.930520e+04
# 8   2.141083e+05
# 9   4.537308e+06
# 10  3.842762e+04
# 11  2.139707e+05
# 12  1.896616e+05
# 13  2.139706e+05
# 14  2.139212e+05
# 15  4.538020e+06
# 16  1.855472e+06
# 17  2.139216e+05
# 18  4.536878e+06
# 19  2.139707e+05
# 20  2.139212e+05
# 21  3.030591e+05
# 22  2.139694e+05
# 23  2.139203e+05
# 24  2.139691e+05
# 25  4.537862e+06
# 26  2.139695e+05
# 27  2.139204e+05
# 28  2.139203e+05
# 29  2.139691e+05
# 30  2.139691e+05

# %%
print(f"Best MAPE: {results['MAPE'].min()}")
print(f"Best performing data: {results.loc[results['MAPE'].argmin()]['Data']}")
print(f"Best parameters: {results.loc[results['MAPE'].argmin()]['Best_parameters']}")
# Out:
# Best MAPE: 38427.619517675776
# Best performing data: dipep_freq+avg_protvec
# Best parameters:  "{'metric': 'euclidean', 'n_neighbors': 1, 'weights': 'uniform'}"

# %% [markdown]
# ### Analysis

# %%
dipep_freq = reduce_by_kmer_frequency(df, kmer=2)

# %%
uniprot_embedding = biovec.models.load_protvec("data/embeddings/uniprot__kmer_3_contextWindow_10_vector_100_reduction_None")

avg_protvec = convert_sequences_to_avg_vectors(df['Sequence'], uniprot_embedding)
avg_protvec = avg_protvec.reset_index(drop=True)
# Out:
# /Users/in-divye.singh/anaconda3/envs/life-science/lib/python3.6/site-packages/smart_open/smart_open_lib.py:254: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# Creating vectors: 100%|██████████| 712/712 [00:00<00:00, 1125.60sequence/s]

# %%
dipep_protvec = pd.concat([avg_protvec, dipep_freq], axis=1)

# %%
from sklearn.neighbors import NearestNeighbors

# %%
def plot_nbr_mic(data, target, n_neighbors=1, metric='euclidean', n_jobs=10):
    data = data.reset_index(drop=True)
    target = target.reset_index(drop=True)
    nearesr_neighbors = NearestNeighbors(n_neighbors=n_neighbors, metric=metric, n_jobs=n_jobs)
    nearesr_neighbors.fit(data)
    grph = nearesr_neighbors.kneighbors_graph(n_neighbors=n_neighbors).todense()
    neighbors = np.where(grph == 1)
    neighbors = np.array([[i]+neighbors[1][np.where(neighbors[0]==i)[0]].tolist() for i in range(data.shape[0])])
    mic_nbrs = np.full(neighbors.shape, np.nan)
    for i in range(mic_nbrs.shape[1]):
        mic_nbrs[:,i] = target[neighbors[:,i]]

    plt.figure(figsize=(5*mic_nbrs.shape[1],50))
    im = plt.imshow(mic_nbrs, cmap='gist_ncar', interpolation='none') #plt.cm.get_cmap('gist_rainbow', 75)
    cbar = plt.colorbar(im)
    cbar.ax.tick_params(labelsize=20)
    cbar.set_label('MIC', fontsize=25)
    plt.axis('auto')
    plt.xlabel('neighbors', fontdict={'size':5*mic_nbrs.shape[1]})
    plt.ylabel('#row', fontdict={'size':5*mic_nbrs.shape[1]})
    plt.xticks(fontsize=5*mic_nbrs.shape[1])
    plt.yticks(fontsize=5*mic_nbrs.shape[1])
    plt.show()

# %% [markdown]
# ### Observation

# %% [markdown]
# For kNN to give good results, sequences which are closer together should have MIC values closer together. But it is seen from below plot that many of the sequences with higher MIC values have low MIC value sequeces as their neighbors. However, as we look at lower MIC value sequences, they start to have low MIC value sequeces as their neighbors.

# %%
plot_nbr_mic(dipep_protvec, df['MIC'], n_neighbors=5)

# %%
mask = df['MIC'] < 1

# %%
plot_nbr_mic(dipep_protvec[mask], df['MIC'][mask], n_neighbors=5)
